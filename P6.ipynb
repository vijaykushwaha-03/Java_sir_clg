# %%
import pandas as pd

# %%
df=pd.read_csv(r"Z:\SEM-3\ML\DATASET\graph_data.csv")

# %%
df
# Out:
#    product  profit  loss
# 0       12      10    34
# 1       23      20    76
# 2       34      30    42
# 3       45      35    98
# 4       56      70    45
# 5       67      34    90

# %%
df.plot(x="product",y=['profit','loss'])
# Out:
# <AxesSubplot:xlabel='product'>

# %%
ax=df.plot.area()

# %%
ax=df.plot.bar(x='product',y='loss')

# %%
ax=df.plot.box()

# %%
ax=df.plot.line()

# %%
ax=df.plot.line(subplots=True)

# %%
ax=df.plot.scatter(x='product',y='profit')

# %%
ax=df.plot.pie(y='profit',figsize=(10,10))

# %%
ax=df.plot.pie(subplots=True,figsize=(10,10))
