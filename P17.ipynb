# %%
import pandas as pd

# %%
df = pd.read_csv(r"Z:\YAER 2\ML\DATASET\Real estate.csv")

# %%
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df=df.rename(columns={'X1 transaction date':'X1_transaction_date'})

# %%
df=df.rename(columns={'X2 house age':'X2_house_age'})

# %%
df
# Out:
#       No  X1_transaction_date  X2_house_age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
plt.xlabel('X1_transaction_date')
plt.ylabel('X2_house_age')
plt.scatter(df.X1_transaction_date,df.X2_house_age,color='red',marker='*')

# %%
new_df=df.drop('X1_transaction_date',axis='columns')
new_df
# Out:
#       No  X2_house_age  X3 distance to the nearest MRT station  \
# 0      1          32.0                                84.87882
# 1      2          19.5                               306.59470
# 2      3          13.3                               561.98450
# 3      4          13.3                               561.98450
# 4      5           5.0                               390.56840
# ..   ...           ...                                     ...
# 409  410          13.7                              4082.01500
# 410  411           5.6                                90.45606
# 411  412          18.8                               390.96960
# 412  413           8.1                               104.81010
# 413  414           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# ...
