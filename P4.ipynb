# %%
import pandas as pd

# %%
df=pd.read_csv(r"Z:\SEM-3\ML\DATASET\Real estate_data.csv")

# %%
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           NaN
# ..   ...                  ...           ...
# 104  105             2012.667          32.7
# 105  106             2012.833           0.0
# 106  107             2013.083          17.2
# 107  108             2013.333          12.2
# 108  109             2013.417          31.4
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                             10.0
# 1                                 306.59470                              9.0
# 2                                 561.98450                              5.0
# 3                                 561.98450                              5.0
# ...

# %%
df_new=df.dropna(how='all')

# %%
df_new
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           NaN
# ..   ...                  ...           ...
# 104  105             2012.667          32.7
# 105  106             2012.833           0.0
# 106  107             2013.083          17.2
# 107  108             2013.333          12.2
# 108  109             2013.417          31.4
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                             10.0
# 1                                 306.59470                              9.0
# 2                                 561.98450                              5.0
# 3                                 561.98450                              5.0
# ...

# %%
df_new=df.dropna(how='any')

# %%
df_new
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 3      4             2013.500          13.3
# 6      7             2012.667          34.5
# 8      9             2013.500          31.7
# ..   ...                  ...           ...
# 104  105             2012.667          32.7
# 105  106             2012.833           0.0
# 106  107             2013.083          17.2
# 107  108             2013.333          12.2
# 108  109             2013.417          31.4
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                             10.0
# 1                                 306.59470                              9.0
# 3                                 561.98450                              5.0
# 6                                 623.47310                              7.0
# ...

# %%
df_new=df.dropna(axis=1)

# %%
df_new
# Out:
#       No
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 104  105
# 105  106
# 106  107
# 107  108
# 108  109
#
# [109 rows x 1 columns]

# %%
df_new=df.dropna(axis=0)

# %%
df_new
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 3      4             2013.500          13.3
# 6      7             2012.667          34.5
# 8      9             2013.500          31.7
# ..   ...                  ...           ...
# 104  105             2012.667          32.7
# 105  106             2012.833           0.0
# 106  107             2013.083          17.2
# 107  108             2013.333          12.2
# 108  109             2013.417          31.4
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                             10.0
# 1                                 306.59470                              9.0
# 3                                 561.98450                              5.0
# 6                                 623.47310                              7.0
# ...

# %%
df["X5 latitude"].mean()
# Out:
# 24.96931048076923

# %%
round(df["X5 latitude"].mean(),2)
# Out:
# 24.97

# %%
df["X5 latitude"].median()
# Out:
# 24.973045

# %%
df["X5 latitude"].mode()
# Out:
# 0    24.95204
# 1    24.97433
# Name: X5 latitude, dtype: float64
