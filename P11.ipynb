# %%
import pandas as pd

# %%
df=pd.read_csv(r"Z:\SEM-3\ML\DATASET\NB_loan_data_set.csv")

# %%
df
# Out:
#      Gender Married  Dependents     Education Self_Employed  Credit_History  \
# 0      Male      No         0.0      Graduate            No             1.0
# 1      Male     Yes         1.0      Graduate            No             1.0
# 2      Male     Yes         0.0      Graduate           Yes             1.0
# 3      Male     Yes         0.0  Not Graduate            No             1.0
# 4      Male      No         0.0      Graduate            No             1.0
# ..      ...     ...         ...           ...           ...             ...
# 277    Male     Yes         0.0      Graduate            No             1.0
# 278    Male     Yes         0.0      Graduate            No             1.0
# 279  Female     Yes         0.0  Not Graduate            No             NaN
# 280    Male      No         1.0  Not Graduate           Yes             0.0
# 281    Male     Yes         0.0      Graduate            No             1.0
#
#     Property_Area  Loan_Status
# ...

# %%
from sklearn.preprocessing import LabelEncoder
Numerics=LabelEncoder()

# %%
df['Gender_new']=Numerics.fit_transform(df['Gender'])
df['Married_new']=Numerics.fit_transform(df['Married'])
df['Dependents_new']=Numerics.fit_transform(df['Dependents'])

# %%
df
# Out:
#      Gender Married  Dependents     Education Self_Employed  Credit_History  \
# 0      Male      No         0.0      Graduate            No             1.0
# 1      Male     Yes         1.0      Graduate            No             1.0
# 2      Male     Yes         0.0      Graduate           Yes             1.0
# 3      Male     Yes         0.0  Not Graduate            No             1.0
# 4      Male      No         0.0      Graduate            No             1.0
# ..      ...     ...         ...           ...           ...             ...
# 277    Male     Yes         0.0      Graduate            No             1.0
# 278    Male     Yes         0.0      Graduate            No             1.0
# 279  Female     Yes         0.0  Not Graduate            No             NaN
# 280    Male      No         1.0  Not Graduate           Yes             0.0
# 281    Male     Yes         0.0      Graduate            No             1.0
#
# ...

# %%
df=df.drop(['Gender_new','Married_new','Dependents_new'],axis=1)

# %%
df
# Out:
#      Gender Married  Dependents     Education Self_Employed  Credit_History  \
# 0      Male      No         0.0      Graduate            No             1.0
# 1      Male     Yes         1.0      Graduate            No             1.0
# 2      Male     Yes         0.0      Graduate           Yes             1.0
# 3      Male     Yes         0.0  Not Graduate            No             1.0
# 4      Male      No         0.0      Graduate            No             1.0
# ..      ...     ...         ...           ...           ...             ...
# 277    Male     Yes         0.0      Graduate            No             1.0
# 278    Male     Yes         0.0      Graduate            No             1.0
# 279  Female     Yes         0.0  Not Graduate            No             NaN
# 280    Male      No         1.0  Not Graduate           Yes             0.0
# 281    Male     Yes         0.0      Graduate            No             1.0
#
#     Property_Area  Loan_Status
# ...

# %%
x=df.iloc[:,[0,2,3]].values
y=df.iloc[:,4].values

# %%
x
# Out:
# array([['Male', 0.0, 'Graduate'],
#        ['Male', 1.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Not Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 2.0, 'Graduate'],
#        ['Male', 0.0, 'Not Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 2.0, 'Graduate'],
#        ['Male', 1.0, 'Graduate'],
#        ['Male', 2.0, 'Graduate'],
#        ['Male', 2.0, 'Graduate'],
#        ['Male', 2.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 2.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 1.0, 'Not Graduate'],
#        ['Female', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Not Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Not Graduate'],
#        ['Male', 1.0, 'Graduate'],
#        ['Male', 0.0, 'Not Graduate'],
#        [nan, 2.0, 'Not Graduate'],
#        ['Male', 1.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
# ...

# %%
y
# Out:
# array(['No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        nan, 'No', 'No', 'No', 'No', 'No', 'No', 'No', nan, 'No', 'No',
#        'No', 'No', nan, 'Yes', 'No', 'No', 'No', nan, nan, 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No',
#        'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', nan, 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', nan,
#        'No', 'No', 'No', nan, 'No', 'Yes', nan, 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No',
#        'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No',
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train
# Out:
# array([['Female', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Female', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Not Graduate'],
#        ['Male', 2.0, 'Graduate'],
#        ['Male', 2.0, 'Not Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Female', 0.0, 'Graduate'],
#        ['Female', 1.0, 'Graduate'],
#        ['Male', 2.0, 'Graduate'],
#        ['Male', 0.0, 'Not Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', nan, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', nan, 'Not Graduate'],
#        ['Male', 2.0, 'Not Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
#        ['Male', 0.0, 'Graduate'],
# ...
